# %% [markdown]
# <a href="https://colab.research.google.com/github/Alekyakarri/Python-programs/blob/main/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#String operations
a=(input())
b=str(input())
#concatination
print(a+b)
#repetition
print(a*3)
print(a[3])
print(a[-1])
print(a[0:2])
# Out:
# Datascience
# Artificialintelligence
# DatascienceArtificialintelligence
# DatascienceDatascienceDatascience
# a
# e
# Da

# %%
# methods in string
c=str(input())
#creates list from string
print(c.split())
#writes string in uppercase
print(c.upper())
print(c)
#writes string in lowercase
print(c.lower())
#
e="_".join(c)
print(e)
d=" apple "
print(d.strip())
print(d.replace(" "," "))
# Out:
# good morning
# ['good', 'morning']
# GOOD MORNING
# good morning
# good morning
# g_o_o_d_ _m_o_r_n_i_n_g
# apple
#  apple

# %%
# Funcgtions in python
#program that count vowels
a=input()
count=0
for i in a:
  if i in "aeiouAEIOU":
     count=count+1
print(count)
# Out:
# alekya
# 3

# %%
# program checks substring and return its index
s1=str(input("Enter string:"))
s2=str(input("Enter substring:"))
if s2 in s1:
  print(s1.find(s2))
else:
  print("no")
# Out:
# Enter string:alekya
# Enter substring:kya
# 3

# %%
# program that prints reverse of a number using functions
x=int(input("Enter:"))
def reverse(z):
  sum=0
  while (z>0):
    rem=z%10
    sum=sum*10+rem
    z=z//10
  return sum
print(reverse(z))
