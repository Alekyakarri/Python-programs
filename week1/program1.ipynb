# %% [markdown]
# <a href="https://colab.research.google.com/github/Alekyakarri/Python-programs/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this code is for Arithmetic operation
x=int(input("Enter x value:"))
y=int(input("Enter y value:"))
print("sum",x+y)
print("difference",x-y)
print("Multiplication",x*y)
print("Division",x/y)
print("modulus",x%y)
print("Exponential",x**y)
print("Division",x//y)
# Out:
# Enter x value:10
# Enter y value:5
# sum 15
# difference 5
# Multiplication 50
# Division 2.0
# modulus 0
# Exponential 100000
# Division 2

# %%
#This is Assignment operator
print(x==y)

# %%
print("Hi!")
print("My name is Alekya")
# Out:
# Hi!
# My name is Alekya

# %%
print("Hello world!")
# Out:
# Hello world!
